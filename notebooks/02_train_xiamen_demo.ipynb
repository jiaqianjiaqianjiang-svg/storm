# %% [markdown]
# # 厦门站 CNN 训练示例
#
# 运行前请先完成 `code_my/Data_preprocessing.ipynb`，确保 `data/processed_xiamen_1985` 中已经生成 `X_train.npy`、`y_train.npy`、`X_val.npy`、`y_val.npy` 等文件。

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / "src"))
PROJECT_ROOT

# %%
from training_utils import resolve_preprocessed_dir, SurgeNpyDataset

data_dir = resolve_preprocessed_dir("data/processed_xiamen_1985")
train_dataset = SurgeNpyDataset(data_dir / "X_train.npy", data_dir / "y_train.npy")
val_dataset = SurgeNpyDataset(data_dir / "X_val.npy", data_dir / "y_val.npy")

print("data_dir:", data_dir)
print("X_train:", train_dataset.x.shape)
print("y_train:", train_dataset.y.shape)
print("X_val:", val_dataset.x.shape)
print("y_val:", val_dataset.y.shape)

# %% [markdown]
# 下面直接调用训练脚本。训练结果会保存到 `runs/xiamen_1985_demo`，不会提交到 GitHub。

# %%
# !python ../src/train_xiamen.py --data-dir ../data/processed_xiamen_1985 --run-dir ../runs/xiamen_1985_demo --epochs 100 --batch-size 16
