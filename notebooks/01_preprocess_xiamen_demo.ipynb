# %% [markdown]
# # Xiamen preprocessing demo
#
# 这个 notebook 只演示如何调用命令行预处理脚本，不保存真实数据到仓库。运行前请确认 `src/config.py` 中的 ERA20C 和 GESLA 路径正确。

# %%
from pathlib import Path

project_root = Path.cwd()
print(project_root)

# %% [markdown]
# ## 测试 1985 单年
#
# 建议先跑单年，确认 GESLA、ERA20C、cfgrib/eccodes 都能正常工作。

# %%
# !python src/preprocess_xiamen.py --start-year 1985 --end-year 1985

# %% [markdown]
# ## 全部年份
#
# 全部年份会生成较大的 `.npy` 文件，请确认 `outputs/xiamen/` 所在磁盘空间充足。

# %%
# !python src/preprocess_xiamen.py --all-years

# %% [markdown]
# ## 查看输出文件
#
# `outputs/` 已被 `.gitignore` 排除，不要把真实输出文件提交到 GitHub。

# %%
output_dir = Path('outputs/xiamen')
if output_dir.exists():
    for path in sorted(output_dir.iterdir()):
        print(path.name)
else:
    print('还没有输出目录，请先运行预处理命令。')
